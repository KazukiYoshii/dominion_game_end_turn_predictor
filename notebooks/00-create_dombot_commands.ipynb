# %%
import discord

# %%
with open("../resources/high_rate_accounts.txt") as f, open("../resources/high_rate_accounts2.txt", "w") as f_out:
    for line in f:
        player = line.split()[1]
        f_out.write(f"{player}\n")

# %%
with open("../resources/high_rate_accounts.txt") as f:
    for line in f:
        print(f"!prior -n 100 -c -p {line}")
# Out:
# !prior -n 100 -c -p Freaky
#
# !prior -n 100 -c -p nasmith99
#
# !prior -n 100 -c -p sillypotter
#
# !prior -n 100 -c -p hakha3
#
# !prior -n 100 -c -p JNails
#
# !prior -n 100 -c -p syamii4
#
# !prior -n 100 -c -p kazumaru0828
#
# !prior -n 100 -c -p hsypsx
#
# !prior -n 100 -c -p Fircoal
#
# !prior -n 100 -c -p heron
#
# !prior -n 100 -c -p sangatsu
#
# !prior -n 100 -c -p pop180
#
# !prior -n 100 -c -p recycle_garbage
#
# !prior -n 100 -c -p yurikamome
#
# !prior -n 100 -c -p SamE
#
# !prior -n 100 -c -p cider01
#
# !prior -n 100 -c -p crabcat2
#
# !prior -n 100 -c -p Lemonspawn
#
# !prior -n 100 -c -p Dingan
#
# !prior -n 100 -c -p Shakalaki
#
# !prior -n 100 -c -p mayakuzuki
#
# !prior -n 100 -c -p Personman
#
# !prior -n 100 -c -p RTT
#
# !prior -n 100 -c -p Mercury444F
#
# !prior -n 100 -c -p auto_pp
#
# !prior -n 100 -c -p russ2
#
# !prior -n 100 -c -p Sicomatic
#
# !prior -n 100 -c -p cha-shu
#
# !prior -n 100 -c -p Jerrydot
#
# !prior -n 100 -c -p schadd
#
# ...

# %%
with open("../resources/game_id_list_pre.txt") as f, open("../resources/game_id_list.txt", "w") as f_out:
    for i, line in enumerate(f):
        tokens = line.split()
        if len(tokens) == 6 and tokens[1] == "—":
            f_out.write(f"{tokens[0]}\n")
